# %% [markdown]
# <a href="https://colab.research.google.com/github/ThanhToan2002/BT/blob/main/Ai_tuan4_24_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install scikit-fuzzy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 994.0/994.0 KB 21.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for scikit-fuzzy: filename=scikit_fuzzy-0.4.2-py3-none-any.whl size=894088 sha256=84ea93dad777d3e245ac5082fb318c988fc66422d2b950fd22478ecbf4cc8c33
#   Stored in directory: /root/.cache/pip/wheels/2c/04/80/7eefb1a2de7d36aefd06432fab2a1486caf0a0596a7067391a
# Successfully built scikit-fuzzy
# ...

# %%
import numpy as np
import skfuzzy as fuzz
import matplotlib.pyplot as plt

# %%
from pyparsing.helpers import line
import numpy as np
import skfuzzy as fuzz
import matplotlib.pyplot as plt
x = np.arange(30,81,1)
slow = fuzz.trimf(x,[30,40,50])
plt.figure()
plt.plot(x,slow,'r',linewidth = 1.5,lable='slow')

# %%
import numpy as np
import skfuzzy as fuzz
import matplotlib.pyplot as plt
x=np.arange(30,81,1)
slow=fuzz.trimf(x,[30,40,50])
medium_fast =fuzz.trimf(x,[50,70,80])
full_fast= fuzz.trimf(x,[30,50,70])
plt.figure()
plt.plot(x,slow,'r',linewidth=1.5,label='slow')
plt.plot(x,medium_fast,'green',linewidth=1.5,label='medium_fast')
plt.plot(x,full_fast,'blue',linewidth=1.5,label='full_fast')

# %%
import numpy as np
import skfuzzy as fuzz
import matplotlib.pyplot as plt
x=np.arange(30,81,1)
slow=fuzz.trimf(x,[0,40,50])
medium_fast =fuzz.trimf(x,[50,70,80])
full_fast= fuzz.trimf(x,[30,50,70])
plt.figure()
plt.plot(x,slow,'r',linewidth=1.5,label='slow')
plt.plot(x,medium_fast,'green',linewidth=1.5,label='medium_fast')
plt.plot(x,full_fast,'blue',linewidth=1.5,label='full_fast')

# %%
import numpy as np
import skfuzzy as fuzz
import matplotlib.pyplot as plt
x=np.arange(30,81,1)
slow=fuzz.trimf(x,[30,30,50])
medium_fast =fuzz.trimf(x,[50,70,80])
full_fast= fuzz.trimf(x,[30,50,70])
plt.figure()
plt.plot(x,slow,'r',linewidth=1.5,label='slow')
plt.plot(x,medium_fast,'green',linewidth=1.5,label='medium_fast')
plt.plot(x,full_fast,'blue',linewidth=1.5,label='full_fast')

# %%
from skfuzzy.membership.generatemf import trapmf
import numpy as np
import skfuzzy as fuzz
import matplotlib.pyplot as plt
x=np.arange(30,81,1)
slow=fuzz.trimf(x,[30,40,50])
medium_fast =fuzz.trimf(x,[50,70,80])
full_fast= fuzz.trimf(x,[30,50,70])
plt.figure()
plt.plot(x,slow,'r',linewidth=1.5,label='slow')
plt.plot(x,medium_fast,'green',linewidth=1.5,label='medium_fast')
plt.plot(x,full_fast,'blue',linewidth=1.5,label='full_fast')
trapmf[0,0,0,0]

# %%
x=np.arange(30,81,1)
slow=fuzz.trimf(x,[30,40,50])
medium_fast =fuzz.trimf(x,[50,70,80])
full_fast= fuzz.trimf(x,[30,50,70])
plt.figure()
plt.plot(x,slow,'r',linewidth=1.5,label='slow')
plt.plot(x,medium_fast,'green',linewidth=1.5,label='medium_fast')
plt.plot(x,full_fast,'blue',linewidth=1.5,label='full_fast')

# %%
import numpy as np
import skfuzzy as fuzz
import matplotlib.pyplot as plt
x=np.arange(30,81,1)
slow=fuzz.trimf(x,[30,40,50])
medium_fast =fuzz.trimf(x,[50,70,80])
full_fast= fuzz.trimf(x,[30,50,70])
plt.figure()
plt.plot(x,slow,'r',linewidth=1.5,label='slow')
plt.plot(x,medium_fast,'green',linewidth=1.5,label='medium_fast')
plt.plot(x,full_fast,'blue',linewidth=1.5,label='full_fast')

# %%
x=np.arange(30,81,1)
slow=fuzz.gaussmf(x,40,5)
medium_fast =fuzz.gaussmf(x,70,8)
full_fast= fuzz.gaussmf(x,50,7)
plt.figure()
plt.plot(x,slow,'r',linewidth=1.5,label='slow')
plt.plot(x,medium_fast,'green',linewidth=1.5,label='medium_fast')
plt.plot(x,full_fast,'blue',linewidth=1.5,label='full_fast')
trapmf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-64-165827c94836> in <module>
#       7 plt.plot(x,medium_fast,'green',linewidth=1.5,label='medium_fast')
#       8 plt.plot(x,full_fast,'blue',linewidth=1.5,label='full_fast')
# ----> 9 trapmf
#
# NameError: name 'trapmf' is not defined

# %%
import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl

# %%
food = ctrl.Antecedent(np.arange(0,11,1),'food')
service = ctrl.Antecedent(np.arange(0,11,1),'service')
tip = ctrl.Antecedent(np.arange(10,31,1),'tip')
food['poor']= fuzz.trimf(food.universe,[0,0,5])
food['average']= fuzz.trimf(food.universe,[5,10,10])
food['good']= fuzz.trimf(food.universe,[6,6,9])
service['poor']= fuzz.trimf(service.universe,[0,0,5])
service['average']= fuzz.trimf(service.universe,[5,10,10])
service['good']= fuzz.trimf(service.universe,[6,6,9])
tip['10%']= fuzz.trimf(tip.universe,[0,0,5])
tip['20%']= fuzz.trimf(tip.universe,[5,10,10])
tip['30%']= fuzz.trimf(tip.universe,[6,6,9])

# %%
x=np.arange(30,81,1)
slow=fuzz.gaussmf(x,40,5)
medium_fast =fuzz.gaussmf(x,70,8)
full_fast= fuzz.gaussmf(x,50,7)
plt.figure()
plt.plot(x,slow,'r',linewidth=1.5,label='slow')
plt.plot(x,medium_fast,'green',linewidth=1.5,label='medium_fast')
plt.plot(x,full_fast,'blue',linewidth=1.5,label='full_fast')
food = ctrl.Antecedent(np.arange(0,11,1),'food')
service = ctrl.Antecedent(np.arange(0,11,1),'service')
tip = ctrl.Antecedent(np.arange(10,31,1),'tip')
food['poor']= fuzz.trimf(food.universe,[0,0,5])
food['average']= fuzz.trimf(food.universe,[5,10,10])
food['good']= fuzz.trimf(food.universe,[6,6,9])
service['poor']= fuzz.trimf(service.universe,[0,0,5])
service['average']= fuzz.trimf(service.universe,[5,10,10])
service['good']= fuzz.trimf(service.universe,[6,6,9])
tip['10%']= fuzz.trimf(tip.universe,[0,0,5])
tip['20%']= fuzz.trimf(tip.universe,[5,10,10])
tip['30%']= fuzz.trimf(tip.universe,[6,6,9])

# %%
food = ctrl.Antecedent(np.arange(0,11,1),'food')
service = ctrl.Antecedent(np.arange(0,11,1),'service')
tip = ctrl.Consequent(np.arange(10,31,1),'tip')
food['poor']= fuzz.trimf(food.universe,[0,0,5])
food['average']= fuzz.trimf(food.universe,[0,5,10])
food['good']= fuzz.trimf(food.universe,[5,10,10])
service['poor']= fuzz.trimf(service.universe,[0,0,5])
service['average']= fuzz.trimf(service.universe,[0,5,10])
service['good']= fuzz.trimf(service.universe,[5,10,10])
tip['10%']= fuzz.trimf(tip.universe,[10,10,10])
tip['20%']= fuzz.trimf(tip.universe,[10,20,30])
tip['30%']= fuzz.trimf(tip.universe,[30,30,30])
food.view()
service.view()
tip.view()
rule1 = ctrl.Rule(food['poor']& service['poor'],tip['10%'])
rule2 = ctrl.Rule(food['poor']& service['average'],tip['10%'])
rule3 = ctrl.Rule(food['poor']& service['good'],tip['10%'])
rule4 = ctrl.Rule(food['average']& service['poor'],tip['20%'])
rule5 = ctrl.Rule(food['average']& service['average'],tip['20%'])
rule6 = ctrl.Rule(food['average']& service['good'],tip['30%'])
rule7 = ctrl.Rule(food['good']& service['poor'],tip['20%'])
rule8 = ctrl.Rule(food['good']& service['average'],tip['30%'])
rule9 = ctrl.Rule(food['good']& service['good'],tip['30%'])
tipping_ctlr= ctrl.ControlSystem([rule1,rule2,rule3,rule4,rule5,rule6,rule7,rule8,rule9])
tipping = ctrl.ControlSystemSimulation(tipping_ctlr)
tipping.input['food']=15
tipping.input['service']=15
tipping.compute()
print(tipping.output['tip'])
tip.view(sim=tipping)
# Out:
# 29.666666666666668
